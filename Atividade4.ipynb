# %% [markdown]
# #Centro de Educação Tecnológica do Amazonas - IBC
# #Curso Técnico em Nível Médio de Inteligência Artificial
# #Manaus 24 de março de 2026
# #Alunos: José Maria - Roberto Cruz

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
n1, n2 = 0, 0
print("Olá mundo!")

print(5+5-2)
print(n1)
print(5**2)
print(n2)
# Out:
# Olá mundo!
# 8
# 0
# 25
# 0

# %%
def dobro(x):
  print(x*2)

dobro(125)

# %%
print("Curso Técnico em Nível Médio de Inteligência Artificial - Turma 2026.1")
# Out:
# Curso Técnico em Nível Médio de Inteligência Artificial - Turma 2026.1
